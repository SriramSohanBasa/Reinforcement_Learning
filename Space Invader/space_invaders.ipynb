# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /private/var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/pip-req-build-sufwuzxk
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /private/var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/pip-req-build-sufwuzxk
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 506bb7aa40e9d90e997580a369f2e9bf64abe594
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.5.0a0 (from rl_zoo3==2.5.0a1)
#   Downloading sb3_contrib-2.5.0a0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from rl_zoo3==2.5.0a1) (1.0.0)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.5.0a1)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from rl_zoo3==2.5.0a1) (4.67.1)
# Collecting rich (from rl_zoo3==2.5.0a1)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting optuna>=3.0 (from rl_zoo3==2.5.0a1)
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting pyyaml>=5.1 (from rl_zoo3==2.5.0a1)
#   Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.5.0a1)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.5.0a1)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (0.0.4)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# Collecting wasabi (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from optuna>=3.0->rl_zoo3==2.5.0a1) (24.2)
# Collecting sqlalchemy>=1.4.2 (from optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading SQLAlchemy-2.0.37-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from pytablewriter~=1.2->rl_zoo3==2.5.0a1) (75.8.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable-baselines3<3.0,>=2.4.0 (from sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl_zoo3==2.5.0a1)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from rich->rl_zoo3==2.5.0a1) (2.19.1)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Collecting filelock (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting requests (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.5.0a1)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting numpy>=1.21.0 (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1)
#   Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting torch>=1.13 (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading torch-2.5.1-cp311-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting pandas (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting matplotlib (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (2.9.0.post0)
# Collecting pytz>=2018.9 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: six>=1.5 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (1.17.0)
# Collecting networkx (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting sympy==1.13.1 (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=0.9.2 (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading fonttools-4.55.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading kiwisolver-1.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow>=8 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (11.1.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting tzdata>=2022.7 (from pandas->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached charset_normalizer-3.4.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1)
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Downloading sb3_contrib-2.5.0a0-py3-none-any.whl (92 kB)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Using cached huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading SQLAlchemy-2.0.37-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.5 MB/s eta 0:00:00
# Downloading stable_baselines3-2.4.1-py3-none-any.whl (183 kB)
# Downloading numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 10.7 MB/s eta 0:00:00a 0:00:01
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading torch-2.5.1-cp311-none-macosx_11_0_arm64.whl (63.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 MB 14.0 MB/s eta 0:00:00a 0:00:01
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
# Downloading matplotlib-3.10.0-cp311-cp311-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 15.6 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 15.2 MB/s eta 0:00:00a 0:00:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.4.1-cp311-cp311-macosx_10_9_universal2.whl (194 kB)
# Downloading contourpy-1.3.1-cp311-cp311-macosx_11_0_arm64.whl (254 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.9 MB/s eta 0:00:00a 0:00:01
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading kiwisolver-1.4.8-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.5.0a1-py3-none-any.whl size=77339 sha256=8a3602b9e76884541631fc8eec076a99ae6014afc10ba28c9d94bd6a530baac2
#   Stored in directory: /private/var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/pip-ephem-wheel-cache-hzzmyibp/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: pytz, mpmath, wasabi, urllib3, tzdata, tcolorpy, sympy, sqlalchemy, pyyaml, pyparsing, pathvalidate, numpy, networkx, mdurl, MarkupSafe, kiwisolver, idna, fsspec, fonttools, filelock, cycler, colorlog, charset-normalizer, chardet, certifi, requests, pandas, mbstrdecoder, markdown-it-py, Mako, jinja2, contourpy, typepy, torch, shimmy, rich, matplotlib, huggingface-hub, alembic, stable-baselines3, optuna, huggingface_sb3, sb3_contrib, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.1
#     Uninstalling numpy-2.2.1:
#       Successfully uninstalled numpy-2.2.1
# Successfully installed DataProperty-1.1.0 Mako-1.3.8 MarkupSafe-3.0.2 alembic-1.14.0 certifi-2024.12.14 chardet-5.2.0 charset-normalizer-3.4.1 colorlog-6.9.0 contourpy-1.3.1 cycler-0.12.1 filelock-3.16.1 fonttools-4.55.3 fsspec-2024.12.0 huggingface-hub-0.27.1 huggingface_sb3-3.0 idna-3.10 jinja2-3.1.5 kiwisolver-1.4.8 markdown-it-py-3.0.0 matplotlib-3.10.0 mbstrdecoder-1.1.3 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 numpy-1.26.4 optuna-4.1.0 pandas-2.2.3 pathvalidate-3.2.3 pyparsing-3.2.1 pytablewriter-1.2.1 pytz-2024.2 pyyaml-6.0.2 requests-2.32.3 rich-13.9.4 rl_zoo3-2.5.0a1 sb3_contrib-2.5.0a0 shimmy-2.0.0 sqlalchemy-2.0.37 stable-baselines3-2.4.1 sympy-1.13.1 tabledata-1.3.4 tcolorpy-0.1.7 torch-2.5.1 typepy-1.3.4 tzdata-2024.2 urllib3-2.3.0 wasabi-1.1.3

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# zsh:1: command not found: apt-get

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# zsh:1: no matches found: gymnasium[atari]
# zsh:1: no matches found: gymnasium[accept-rom-license]

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
from pyvirtualdisplay import Display

# Create a virtual display with additional options
virtual_display = Display(visible=0, size=(1400, 900), backend="xvfb", use_xauth=True)
virtual_display.start()

print("Virtual display started!")
# Out:
# Virtual display started!

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 338049836
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 100000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.10.1+6a7e0ae)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cpu device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 55       |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1830     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 592      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.48e+03 |
# |    ep_rew_mean      | 60       |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1783     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | 78.8     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1779     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1834     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 90       |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1854     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1871     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1882     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1886     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1895     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1898     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1907     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1909     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7661     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1923     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.062    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1927     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.0103   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1933     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1932     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1935     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1939     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1938     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 12536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1942     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 13017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1949     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 13971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1951     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 14797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1950     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 15330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1954     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1951     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1950     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 17398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1952     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 17915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1951     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 18578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1952     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 19181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1952     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 19922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1951     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 20842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1950     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 21532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1951     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 22177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1954     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1955     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 24114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1954     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 24731    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=240.00 +/- 62.53
# Episode length: 2011.40 +/- 219.24
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.01e+03 |
# |    mean_reward      | 240      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1696     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 25420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1700     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 26190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1701     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 26580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1705     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 27212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1707     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 27629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1711     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 28133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1716     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 28849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1718     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 29296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1727     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 30544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1730     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 31322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1734     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 31966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1735     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 32654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1738     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 33357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1742     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 33925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1745     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 34633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1748     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 35269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1751     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 35770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1753     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 36440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1757     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 36948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1761     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 37780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1769     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 39115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1771     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 39646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1773     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 40302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1775     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 40803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1777     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 41529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1780     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 42096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1780     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 42604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1781     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 43355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1783     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 43821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1788     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 44906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1790     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 45851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1790     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 46493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1792     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 47255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1794     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 47825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1795     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 48397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1797     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 49124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1793     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 49588    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=245.00 +/- 55.14
# Episode length: 2320.60 +/- 338.20
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.32e+03 |
# |    mean_reward      | 245      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1653     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 50198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1653     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 50854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1654     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 51390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1653     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 51829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1655     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 52380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1658     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 52981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1664     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 54046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1665     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 54548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1667     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 55112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1668     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 55615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1670     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 56306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1672     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 56775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1675     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 57469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1677     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 57986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1680     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 58870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1682     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 59456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1682     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 59894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1684     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 60455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1685     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 60802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1686     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 61351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1689     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 61990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1690     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 62532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1691     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 63183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1694     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 63958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1695     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 64421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1696     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 64896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1698     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 65604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1699     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 66167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1701     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 66840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1702     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 67603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1703     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 68207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1706     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 69276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1706     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 69824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1708     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 70490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1710     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 71341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1712     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 72049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1713     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 72410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1713     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 72752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1718     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1719     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74761    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=267.00 +/- 17.78
# Episode length: 2098.20 +/- 134.24
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.1e+03  |
# |    mean_reward      | 267      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1648     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 75439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1649     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1650     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1652     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 77267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1655     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 78197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1657     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 78830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1658     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 79349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1659     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 79836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1660     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 80421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1663     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 81319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1665     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 81961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1665     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 82407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 1668     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 83345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 1669     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 83952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 1671     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 84593    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 1672     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 84962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1676     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 86451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 1678     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 87209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 1679     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 87733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 1679     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 88408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 1681     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 88945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1681     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 89454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 1683     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 89980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 1684     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 90590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 1687     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 91696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 1688     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 92286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 1689     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 92817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 1690     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 93255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 1691     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 93784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 1693     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 94920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 1694     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 95425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1695     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 96066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 1696     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 96424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 1698     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 97330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 1699     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 97972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 1701     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 98922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1702     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 99584    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=253.00 +/- 19.13
# Episode length: 2105.40 +/- 279.72
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.11e+03 |
# |    mean_reward      | 253      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_2

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 4000  --folder logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+6a7e0ae)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 270.00
# Atari Episode Length 2151
# Atari Episode Score: 280.00
# Atari Episode Length 2113
# Atari Episode Score: 270.00
# Atari Episode Length 2151
# Atari Episode Score: 260.00
# Atari Episode Length 2211
# Atari Episode Score: 300.00
# Atari Episode Length 3123
# Atari Episode Score: 285.00
# Atari Episode Length 2071

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
# from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
# notebook_login()
# !git config --global credential.helper store

from huggingface_hub import HfApi, HfFolder

# Paste your token here
token = "your_api_key"

# Save the token to Hugging Face's credential store
HfFolder.save_token(token)

# Verify the token
api = HfApi()
user_info = api.whoami()
print(f"Logged in as: {user_info['name']}")
# Out:
# Logged in as: SriramSohan

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga SriramSohan -f logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+6a7e0ae)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to SriramSohan/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 16 files:   0%|                                 | 0/16 [00:00<?, ?it/s]
# (…)oFrameskip-v4/_stable_baselines3_version: 100%|█| 5.00/5.00 [00:00<00:00, 79.
#
# config.yml: 100%|██████████████████████████████| 548/548 [00:00<00:00, 10.7MB/s]
#
# args.yml:   0%|                                     | 0.00/1.24k [00:00<?, ?B/s]
# args.yml: 100%|████████████████████████████| 1.24k/1.24k [00:00<00:00, 3.50MB/s]
# dqn-SpaceInvadersNoFrameskip-v4/data: 100%|██| 208k/208k [00:00<00:00, 4.69MB/s]
#
# README.md: 100%|███████████████████████████| 1.30k/1.30k [00:00<00:00, 21.7MB/s]
# Fetching 16 files:  19%|████▋                    | 3/16 [00:00<00:00, 14.06it/s]
# (…)ceInvadersNoFrameskip-v4/system_info.txt: 100%|█| 274/274 [00:00<00:00, 4.40M
#
# results.json: 100%|████████████████████████████| 152/152 [00:00<00:00, 2.92MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 0.00/13.7M [00:00<?, ?B/s]
#
# env_kwargs.yml: 100%|█████████████████████████| 23.0/23.0 [00:00<00:00, 402kB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  76%|▊| 10.5M/13.7M [00:01<00:00, 10.1MB/s]
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 13.7M/13.7M [00:01<00:00, 9.54MB/s]
# Fetching 16 files: 100%|████████████████████████| 16/16 [00:01<00:00,  9.50it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /Users/sriramsohan/Documents/projects/Reinforcement_Learning/hub/dqn-SpaceInvadersNoFrameskip-v4/rl-video-step-0-to-step-1000.mp4
# MoviePy - Building video /Users/sriramsohan/Documents/projects/Reinforcement_Learning/hub/dqn-SpaceInvadersNoFrameskip-v4/rl-video-step-0-to-step-1000.mp4.
# MoviePy - Writing video /Users/sriramsohan/Documents/projects/Reinforcement_Learning/hub/dqn-SpaceInvadersNoFrameskip-v4/rl-video-step-0-to-step-1000.mp4
#
# MoviePy - Done !
# MoviePy - video ready /Users/sriramsohan/Documents/projects/Reinforcement_Learning/hub/dqn-SpaceInvadersNoFrameskip-v4/rl-video-step-0-to-step-1000.mp4
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 13.7M/13.7M [00:01<00:00, 11.0MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/SriramSohan/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100%|█████| 27.2M/27.2M [00:01<00:00, 16.2MB/s]
# config.yml: 100%|██████████████████████████████| 548/548 [00:00<00:00, 3.60MB/s]
# No normalization file
# args.yml: 100%|████████████████████████████████| 887/887 [00:00<00:00, 6.48MB/s]
# env_kwargs.yml: 100%|████████████████████████| 3.00/3.00 [00:00<00:00, 27.5kB/s]
# train_eval_metrics.zip: 100%|████████████████| 244k/244k [00:00<00:00, 22.8MB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+6a7e0ae)
# [Powered by Stella]
# Stacking 4 frames
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/rl_zoo3/enjoy.py", line 287, in <module>
#     enjoy()
#   File "/Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/rl_zoo3/enjoy.py", line 195, in enjoy
#     model = ALGOS[algo].load(model_path, custom_objects=custom_objects, device=args.device, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/stable_baselines3/common/base_class.py", line 680, in load
#     data, params, pytorch_variables = load_from_zip_file(
#                                       ^^^^^^^^^^^^^^^^^^^
#   File "/Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/stable_baselines3/common/save_util.py", line 434, in load_from_zip_file
#     data = json_to_data(json_data, custom_objects=custom_objects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/stable_baselines3/common/save_util.py", line 165, in json_to_data
#     deserialized_object = cloudpickle.loads(base64_object)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'gym'

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
