# %% [markdown]
# # Unit 6: Advantage Actor Critic (A2C) using Robotics Simulations with Panda-Gym 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/thumbnail.png"  alt="Thumbnail"/>
#
# In this notebook, you'll learn to use A2C with [Panda-Gym](https://github.com/qgallouedec/panda-gym). You're going **to train a robotic arm** (Franka Emika Panda robot) to perform a task:
#
# - `Reach`: the robot must place its end-effector at a target position.
#
# After that, you'll be able **to train in other robotics tasks**.

# %% [markdown]
# ### 🎮 Environments:
#
# - [Panda-Gym](https://github.com/qgallouedec/panda-gym)
#
# ###📚 RL-Library:
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Panda-Gym**, the environment library.
# - Be able to **train robots using A2C**.
# - Understand why **we need to normalize the input**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [Actor-Critic methods by reading Unit 6](https://huggingface.co/deep-rl-course/unit6/introduction) 🤗

# %% [markdown]
# # Let's train our first robots 🤖

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process),  you need to push your trained model to the Hub and get the following results:
#
# - `PandaReachDense-v3` get a result of >= -3.5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900), backend='xvfb')
virtual_display.start()

# sudo mkdir /tmp/.X11-unix
# sudo chmod 1777 /tmp/.X11-unix

# %% [markdown]
# ### Install dependencies 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones:
# - `gymnasium`
# - `panda-gym`: Contains the robotics arm environments.
# - `stable-baselines3`: The SB3 deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
# - `huggingface_hub`: Library allowing anyone to work with the Hub repositories.
#
# ⏲ The installation can **take 10 minutes**.

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# Out:
# zsh:1: no matches found: stable-baselines3[extra]
# Requirement already satisfied: gymnasium in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium) (0.0.4)

# %%
# !pip install huggingface_sb3
# !pip install huggingface_hub
# !pip install panda_gym
# Out:
# Requirement already satisfied: huggingface_sb3 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_sb3) (0.27.1)
# Requirement already satisfied: pyyaml~=6.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_sb3) (6.0)
# Requirement already satisfied: wasabi in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_sb3) (3.1.1)
# Requirement already satisfied: filelock in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (24.2)
# Requirement already satisfied: requests in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.12.14)
# Requirement already satisfied: huggingface_hub in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (0.27.1)
# Requirement already satisfied: filelock in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: requests in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from requests->huggingface_hub) (2024.12.14)
# Collecting panda_gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from panda_gym) (1.0.0)
# Collecting pybullet (from panda_gym)
#   Downloading pybullet-3.2.6.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 7.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from panda_gym) (1.26.4)
# Collecting scipy (from panda_gym)
#   Downloading scipy-1.15.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium>=0.26->panda_gym) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium>=0.26->panda_gym) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages (from gymnasium>=0.26->panda_gym) (0.0.4)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Downloading scipy-1.15.1-cp311-cp311-macosx_14_0_arm64.whl (24.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 9.3 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.6-cp311-cp311-macosx_11_0_arm64.whl size=67921274 sha256=88e6ca90f368e094de3ce5fd86fb245acb4b9e08af7b5afa96c7cc7d8adbf32a
#   Stored in directory: /Users/sriramsohan/Library/Caches/pip/wheels/29/ee/ef/afb46a713feb63a299a9146e5c65d7370576749b5ad5270297
# Successfully built pybullet
# Installing collected packages: pybullet, scipy, panda_gym
# Successfully installed panda_gym-3.0.7 pybullet-3.2.6 scipy-1.15.1

# %% [markdown]
# ## Import the packages 📦

# %%
import os

import gymnasium as gym
import panda_gym

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login

# %% [markdown]
# ## PandaReachDense-v3 🦾
#
# The agent we're going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the *end-effector* is the device at the end of a robotic arm designed to interact with the environment.
#
# In `PandaReach`, the robot must place its end-effector at a target position (green ball).
#
# We're going to use the dense version of this environment. It means we'll get a *dense reward function* that **will provide a reward at each timestep** (the closer the agent is to completing the task, the higher the reward). Contrary to a *sparse reward function* where the environment **return a reward if and only if the task is completed**.
#
# Also, we're going to use the *End-effector displacement control*, it means the **action corresponds to the displacement of the end-effector**. We don't control the individual motion of each joint (joint control).
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/robotics.jpg"  alt="Robotics"/>
#
#
# This way **the training will be easier**.

# %% [markdown]
# ### Create the environment
#
# #### The environment 🎮
#
# In `PandaReachDense-v3` the robotic arm must place its end-effector at a target position (green ball).

# %%
env_id = "PandaReachDense-v3"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space
# Out:
# pybullet build time: Jan 16 2025 16:12:14
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation {'achieved_goal': array([3.8048081, 4.3572826, 7.953891 ], dtype=float32), 'desired_goal': array([4.488077 , 8.40155  , 5.5774198], dtype=float32), 'observation': array([ 4.701392  , -0.32499135, -9.898399  , -7.695214  ,  0.6393088 ,
#         9.20053   ], dtype=float32)}

# %% [markdown]
# The observation space **is a dictionary with 3 different elements**:
# - `achieved_goal`: (x,y,z) the current position of the end-effector.
# - `desired_goal`: (x,y,z) the target position for the end-effector.
# - `observation`: position (x,y,z) and velocity of the end-effector (vx, vy, vz).
#
# Given it's a dictionary as observation, **we will need to use a MultiInputPolicy policy instead of MlpPolicy**.

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box(-1.0, 1.0, (3,), float32)
# Action Space Sample [ 0.5182154  -0.16700651  0.73544014]

# %% [markdown]
# The action space is a vector with 3 values:
# - Control x, y, z movement

# %% [markdown]
# ### Normalize observation and rewards

# %% [markdown]
# A good practice in reinforcement learning is to [normalize input features](https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html).
#
# For that purpose, there is a wrapper that will compute a running average and standard deviation of input features.
#
# We also normalize rewards with this same wrapper by adding `norm_reward = True`
#
# [You should check the documentation to fill this cell](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)

# %%
env = make_vec_env(env_id, n_envs=4)

# Adding this wrapper to normalize the observation and the reward
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10)# TODO: Add the wrapper
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %% [markdown]
# #### Solution

# %%
env = make_vec_env(env_id, n_envs=4)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# ### Create the A2C Model 🤖
#
# For more information about A2C implementation with StableBaselines3 check: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html#notes
#
# To find the best parameters I checked the [official trained agents by Stable-Baselines3 team](https://huggingface.co/sb3).

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)# Create the A2C model and try to find the best parameters
# Out:
# Using cpu device

# %% [markdown]
# #### Solution

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)

# %% [markdown]
# ### Train the A2C agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~25-40min

# %%
model.learn(1_000_000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31.9     |
# |    ep_rew_mean        | -6.02    |
# |    success_rate       | 0.541    |
# | time/                 |          |
# |    fps                | 1328     |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1839     |
# |    policy_loss        | 0.219    |
# |    std                | 1.03     |
# |    value_loss         | 0.0111   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.2     |
# |    ep_rew_mean        | -4.62    |
# |    success_rate       | 0.62     |
# | time/                 |          |
# |    fps                | 1370     |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1939     |
# |    policy_loss        | 5.21     |
# |    std                | 1.02     |
# |    value_loss         | 4.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.9     |
# |    ep_rew_mean        | -3.23    |
# |    success_rate       | 0.8      |
# | time/                 |          |
# |    fps                | 1381     |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.708    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2039     |
# |    policy_loss        | 0.738    |
# |    std                | 1.01     |
# |    value_loss         | 0.333    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.4     |
# |    ep_rew_mean        | -2.39    |
# |    success_rate       | 0.88     |
# | time/                 |          |
# |    fps                | 1377     |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.25    |
# |    explained_variance | 0.532    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2139     |
# |    policy_loss        | 0.341    |
# |    std                | 0.997    |
# |    value_loss         | 0.352    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.1     |
# |    ep_rew_mean        | -1.81    |
# |    success_rate       | 0.95     |
# | time/                 |          |
# |    fps                | 1369     |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.23    |
# |    explained_variance | -0.475   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2239     |
# |    policy_loss        | 0.825    |
# |    std                | 0.992    |
# |    value_loss         | 0.264    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.61     |
# |    ep_rew_mean        | -0.764   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1368     |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | 0.533    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2339     |
# |    policy_loss        | 0.188    |
# |    std                | 0.973    |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.67     |
# |    ep_rew_mean        | -0.604   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1371     |
# |    iterations         | 700      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.13    |
# |    explained_variance | 0.531    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2439     |
# |    policy_loss        | -0.454   |
# |    std                | 0.96     |
# |    value_loss         | 0.015    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.63     |
# |    ep_rew_mean        | -0.387   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1373     |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.08    |
# |    explained_variance | 0.134    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2539     |
# |    policy_loss        | 0.0128   |
# |    std                | 0.944    |
# |    value_loss         | 0.00218  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.81     |
# |    ep_rew_mean        | -0.406   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1379     |
# |    iterations         | 900      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.03    |
# |    explained_variance | -0.127   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2639     |
# |    policy_loss        | 0.0487   |
# |    std                | 0.926    |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.73     |
# |    ep_rew_mean        | -0.303   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1376     |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -3.97    |
# |    explained_variance | 0.338    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2739     |
# |    policy_loss        | -0.0856  |
# |    std                | 0.911    |
# |    value_loss         | 0.00197  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.62     |
# |    ep_rew_mean        | -0.287   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1382     |
# |    iterations         | 1100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -3.93    |
# |    explained_variance | -0.0911  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2839     |
# |    policy_loss        | 0.0821   |
# |    std                | 0.896    |
# |    value_loss         | 0.00306  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.23     |
# |    ep_rew_mean        | -0.252   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1385     |
# |    iterations         | 1200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 0.622    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2939     |
# |    policy_loss        | -0.0139  |
# |    std                | 0.886    |
# |    value_loss         | 0.000311 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.43     |
# |    ep_rew_mean        | -0.28    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1389     |
# |    iterations         | 1300     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -3.85    |
# |    explained_variance | 0.58     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3039     |
# |    policy_loss        | 0.0854   |
# |    std                | 0.875    |
# |    value_loss         | 0.00134  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.27     |
# |    ep_rew_mean        | -0.256   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1389     |
# |    iterations         | 1400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -3.82    |
# |    explained_variance | 0.549    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3139     |
# |    policy_loss        | -0.116   |
# |    std                | 0.863    |
# |    value_loss         | 0.00143  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.27     |
# |    ep_rew_mean        | -0.251   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1389     |
# |    iterations         | 1500     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -3.78    |
# |    explained_variance | 0.433    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3239     |
# |    policy_loss        | -0.0961  |
# |    std                | 0.853    |
# |    value_loss         | 0.00128  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1390     |
# |    iterations         | 1600     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -3.75    |
# |    explained_variance | 0.458    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3339     |
# |    policy_loss        | 0.00924  |
# |    std                | 0.845    |
# |    value_loss         | 0.00029  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.45     |
# |    ep_rew_mean        | -0.27    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1392     |
# |    iterations         | 1700     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -3.72    |
# |    explained_variance | 0.32     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3439     |
# |    policy_loss        | 0.105    |
# |    std                | 0.837    |
# |    value_loss         | 0.00297  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.87     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1392     |
# |    iterations         | 1800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -3.7     |
# |    explained_variance | 0.691    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3539     |
# |    policy_loss        | 0.0551   |
# |    std                | 0.831    |
# |    value_loss         | 0.000646 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.15     |
# |    ep_rew_mean        | -0.256   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1395     |
# |    iterations         | 1900     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -3.67    |
# |    explained_variance | 0.497    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3639     |
# |    policy_loss        | -0.0449  |
# |    std                | 0.824    |
# |    value_loss         | 0.000676 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.246   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1396     |
# |    iterations         | 2000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -3.63    |
# |    explained_variance | 0.862    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3739     |
# |    policy_loss        | 0.0278   |
# |    std                | 0.812    |
# |    value_loss         | 0.00031  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.04     |
# |    ep_rew_mean        | -0.242   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1399     |
# |    iterations         | 2100     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -3.62    |
# |    explained_variance | 0.455    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3839     |
# |    policy_loss        | 0.00934  |
# |    std                | 0.81     |
# |    value_loss         | 0.000493 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.06     |
# |    ep_rew_mean        | -0.245   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1399     |
# |    iterations         | 2200     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -3.59    |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3939     |
# |    policy_loss        | -0.0338  |
# |    std                | 0.802    |
# |    value_loss         | 0.000254 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.11     |
# |    ep_rew_mean        | -0.249   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1401     |
# |    iterations         | 2300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -3.56    |
# |    explained_variance | -1.92    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4039     |
# |    policy_loss        | 0.037    |
# |    std                | 0.793    |
# |    value_loss         | 0.00338  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.23    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1403     |
# |    iterations         | 2400     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -3.55    |
# |    explained_variance | 0.792    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4139     |
# |    policy_loss        | -0.0215  |
# |    std                | 0.791    |
# |    value_loss         | 0.000331 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.231   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1403     |
# |    iterations         | 2500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -3.54    |
# |    explained_variance | 0.439    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4239     |
# |    policy_loss        | -0.0803  |
# |    std                | 0.789    |
# |    value_loss         | 0.00201  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1402     |
# |    iterations         | 2600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -3.52    |
# |    explained_variance | 0.521    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4339     |
# |    policy_loss        | -0.028   |
# |    std                | 0.784    |
# |    value_loss         | 0.000302 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.236   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1403     |
# |    iterations         | 2700     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -3.49    |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4439     |
# |    policy_loss        | -0.0748  |
# |    std                | 0.776    |
# |    value_loss         | 0.000651 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.22     |
# |    ep_rew_mean        | -0.251   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1402     |
# |    iterations         | 2800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.715    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4539     |
# |    policy_loss        | 0.0439   |
# |    std                | 0.769    |
# |    value_loss         | 0.00115  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.207   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1404     |
# |    iterations         | 2900     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -3.44    |
# |    explained_variance | 0.379    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4639     |
# |    policy_loss        | 0.0651   |
# |    std                | 0.762    |
# |    value_loss         | 0.0013   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.237   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1405     |
# |    iterations         | 3000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.805    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4739     |
# |    policy_loss        | 0.0212   |
# |    std                | 0.758    |
# |    value_loss         | 0.000192 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.69     |
# |    ep_rew_mean        | -0.204   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1405     |
# |    iterations         | 3100     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -3.41    |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4839     |
# |    policy_loss        | 0.0343   |
# |    std                | 0.754    |
# |    value_loss         | 0.000354 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1406     |
# |    iterations         | 3200     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.328    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4939     |
# |    policy_loss        | -0.015   |
# |    std                | 0.757    |
# |    value_loss         | 0.000438 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.03     |
# |    ep_rew_mean        | -0.235   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1406     |
# |    iterations         | 3300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -3.4     |
# |    explained_variance | 0.2      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5039     |
# |    policy_loss        | -0.0691  |
# |    std                | 0.751    |
# |    value_loss         | 0.00192  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.04     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1407     |
# |    iterations         | 3400     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 0.744    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5139     |
# |    policy_loss        | -0.0023  |
# |    std                | 0.75     |
# |    value_loss         | 0.000207 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1407     |
# |    iterations         | 3500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5239     |
# |    policy_loss        | 0.0507   |
# |    std                | 0.747    |
# |    value_loss         | 0.000466 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.09     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1408     |
# |    iterations         | 3600     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -3.36    |
# |    explained_variance | 0.446    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5339     |
# |    policy_loss        | -0.0672  |
# |    std                | 0.744    |
# |    value_loss         | 0.000928 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.15     |
# |    ep_rew_mean        | -0.246   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1410     |
# |    iterations         | 3700     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -3.36    |
# |    explained_variance | 0.506    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5439     |
# |    policy_loss        | 0.105    |
# |    std                | 0.741    |
# |    value_loss         | 0.00243  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.01     |
# |    ep_rew_mean        | -0.242   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1411     |
# |    iterations         | 3800     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.36    |
# |    explained_variance | 0.775    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5539     |
# |    policy_loss        | -0.0196  |
# |    std                | 0.744    |
# |    value_loss         | 0.00126  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1412     |
# |    iterations         | 3900     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0.749    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5639     |
# |    policy_loss        | 0.0371   |
# |    std                | 0.739    |
# |    value_loss         | 0.00029  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.05     |
# |    ep_rew_mean        | -0.247   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1414     |
# |    iterations         | 4000     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.33    |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5739     |
# |    policy_loss        | -0.0123  |
# |    std                | 0.736    |
# |    value_loss         | 0.00031  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.234   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1415     |
# |    iterations         | 4100     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.33    |
# |    explained_variance | 0.96     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5839     |
# |    policy_loss        | -0.0168  |
# |    std                | 0.735    |
# |    value_loss         | 6.7e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1416     |
# |    iterations         | 4200     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.3     |
# |    explained_variance | 0.583    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5939     |
# |    policy_loss        | 0.000228 |
# |    std                | 0.729    |
# |    value_loss         | 0.000616 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1417     |
# |    iterations         | 4300     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.28    |
# |    explained_variance | 0.741    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6039     |
# |    policy_loss        | 0.0375   |
# |    std                | 0.724    |
# |    value_loss         | 0.000427 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1418     |
# |    iterations         | 4400     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.26    |
# |    explained_variance | 0.759    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6139     |
# |    policy_loss        | 0.0254   |
# |    std                | 0.719    |
# |    value_loss         | 0.000323 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.09     |
# |    ep_rew_mean        | -0.252   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1419     |
# |    iterations         | 4500     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.24    |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6239     |
# |    policy_loss        | -0.0958  |
# |    std                | 0.715    |
# |    value_loss         | 0.00137  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1420     |
# |    iterations         | 4600     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.23    |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6339     |
# |    policy_loss        | 0.0131   |
# |    std                | 0.711    |
# |    value_loss         | 0.000155 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.236   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1420     |
# |    iterations         | 4700     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.2     |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6439     |
# |    policy_loss        | -0.0102  |
# |    std                | 0.704    |
# |    value_loss         | 3.73e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.236   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1420     |
# |    iterations         | 4800     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.18    |
# |    explained_variance | 0.892    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6539     |
# |    policy_loss        | 0.0248   |
# |    std                | 0.699    |
# |    value_loss         | 0.000244 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1421     |
# |    iterations         | 4900     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6639     |
# |    policy_loss        | -0.00426 |
# |    std                | 0.696    |
# |    value_loss         | 7.88e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.212   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1422     |
# |    iterations         | 5000     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0.703    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6739     |
# |    policy_loss        | 0.0206   |
# |    std                | 0.695    |
# |    value_loss         | 0.000203 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1423     |
# |    iterations         | 5100     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.099    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6839     |
# |    policy_loss        | 0.0612   |
# |    std                | 0.691    |
# |    value_loss         | 0.00114  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1424     |
# |    iterations         | 5200     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.13    |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6939     |
# |    policy_loss        | -0.00768 |
# |    std                | 0.688    |
# |    value_loss         | 0.000113 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.223   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1425     |
# |    iterations         | 5300     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.11    |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7039     |
# |    policy_loss        | -0.0557  |
# |    std                | 0.683    |
# |    value_loss         | 0.00045  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.212   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1426     |
# |    iterations         | 5400     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.07    |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7139     |
# |    policy_loss        | -0.0394  |
# |    std                | 0.676    |
# |    value_loss         | 0.000235 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.218   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1427     |
# |    iterations         | 5500     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0.824    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7239     |
# |    policy_loss        | -0.00494 |
# |    std                | 0.669    |
# |    value_loss         | 0.000159 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1427     |
# |    iterations         | 5600     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7339     |
# |    policy_loss        | -0.0221  |
# |    std                | 0.662    |
# |    value_loss         | 0.000225 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1428     |
# |    iterations         | 5700     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3       |
# |    explained_variance | 0.822    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7439     |
# |    policy_loss        | 0.0151   |
# |    std                | 0.659    |
# |    value_loss         | 0.000343 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.87     |
# |    ep_rew_mean        | -0.23    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1428     |
# |    iterations         | 5800     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.913    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7539     |
# |    policy_loss        | 0.00048  |
# |    std                | 0.662    |
# |    value_loss         | 8.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.215   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1429     |
# |    iterations         | 5900     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7639     |
# |    policy_loss        | -0.0381  |
# |    std                | 0.658    |
# |    value_loss         | 0.00039  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.75     |
# |    ep_rew_mean        | -0.21    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1429     |
# |    iterations         | 6000     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.826    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7739     |
# |    policy_loss        | -0.016   |
# |    std                | 0.657    |
# |    value_loss         | 0.000259 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.217   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1429     |
# |    iterations         | 6100     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7839     |
# |    policy_loss        | 0.000441 |
# |    std                | 0.657    |
# |    value_loss         | 0.000182 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1430     |
# |    iterations         | 6200     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.837    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7939     |
# |    policy_loss        | 0.0218   |
# |    std                | 0.652    |
# |    value_loss         | 0.000418 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.72     |
# |    ep_rew_mean        | -0.204   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1431     |
# |    iterations         | 6300     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | 0.853    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8039     |
# |    policy_loss        | 0.0254   |
# |    std                | 0.646    |
# |    value_loss         | 0.000351 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.68     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1431     |
# |    iterations         | 6400     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8139     |
# |    policy_loss        | 0.0304   |
# |    std                | 0.643    |
# |    value_loss         | 0.000218 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.211   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1432     |
# |    iterations         | 6500     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8239     |
# |    policy_loss        | 0.00954  |
# |    std                | 0.64     |
# |    value_loss         | 0.000159 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.214   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1432     |
# |    iterations         | 6600     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -2.88    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8339     |
# |    policy_loss        | -0.0104  |
# |    std                | 0.635    |
# |    value_loss         | 0.000261 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -0.218   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1433     |
# |    iterations         | 6700     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 0.852    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8439     |
# |    policy_loss        | -0.00175 |
# |    std                | 0.634    |
# |    value_loss         | 0.000321 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1433     |
# |    iterations         | 6800     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 0.945    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8539     |
# |    policy_loss        | 0.00916  |
# |    std                | 0.631    |
# |    value_loss         | 0.00013  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# ...
# | time/                 |          |
# |    fps                | 1412     |
# |    iterations         | 47800    |
# |    time_elapsed       | 676      |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | 0.314    |
# |    explained_variance | 0.868    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49539    |
# |    policy_loss        | 0.0137   |
# |    std                | 0.261    |
# |    value_loss         | 0.00232  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1412     |
# |    iterations         | 47900    |
# |    time_elapsed       | 678      |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | 0.311    |
# |    explained_variance | 0.823    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49639    |
# |    policy_loss        | 0.0156   |
# |    std                | 0.261    |
# |    value_loss         | 0.00162  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.64     |
# |    ep_rew_mean        | -0.196   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48000    |
# |    time_elapsed       | 679      |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | 0.316    |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49739    |
# |    policy_loss        | 0.00941  |
# |    std                | 0.261    |
# |    value_loss         | 0.000312 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.99     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48100    |
# |    time_elapsed       | 680      |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | 0.325    |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49839    |
# |    policy_loss        | 0.00159  |
# |    std                | 0.259    |
# |    value_loss         | 0.000997 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.05     |
# |    ep_rew_mean        | -0.241   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48200    |
# |    time_elapsed       | 682      |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | 0.325    |
# |    explained_variance | 0.876    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49939    |
# |    policy_loss        | 0.0326   |
# |    std                | 0.259    |
# |    value_loss         | 0.0018   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.11     |
# |    ep_rew_mean        | -0.246   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48300    |
# |    time_elapsed       | 683      |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | 0.322    |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50039    |
# |    policy_loss        | 0.0135   |
# |    std                | 0.26     |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5        |
# |    ep_rew_mean        | -0.459   |
# |    success_rate       | 0.96     |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48400    |
# |    time_elapsed       | 684      |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | 0.327    |
# |    explained_variance | 0.915    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50139    |
# |    policy_loss        | -0.00862 |
# |    std                | 0.259    |
# |    value_loss         | 0.282    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.2      |
# |    ep_rew_mean        | -0.334   |
# |    success_rate       | 0.98     |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48500    |
# |    time_elapsed       | 686      |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | 0.326    |
# |    explained_variance | 0.692    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50239    |
# |    policy_loss        | -0.00363 |
# |    std                | 0.258    |
# |    value_loss         | 0.000774 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48600    |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | 0.331    |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50339    |
# |    policy_loss        | -0.00205 |
# |    std                | 0.258    |
# |    value_loss         | 0.00183  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.12     |
# |    ep_rew_mean        | -0.24    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48700    |
# |    time_elapsed       | 689      |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | 0.319    |
# |    explained_variance | 0.914    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50439    |
# |    policy_loss        | 0.00796  |
# |    std                | 0.257    |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48800    |
# |    time_elapsed       | 690      |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | 0.338    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50539    |
# |    policy_loss        | 0.0119   |
# |    std                | 0.257    |
# |    value_loss         | 0.00522  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.19     |
# |    ep_rew_mean        | -0.246   |
# |    success_rate       | 0.99     |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 48900    |
# |    time_elapsed       | 691      |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | 0.337    |
# |    explained_variance | -74.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50639    |
# |    policy_loss        | -0.0184  |
# |    std                | 0.257    |
# |    value_loss         | 0.293    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.92     |
# |    ep_rew_mean        | -0.223   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49000    |
# |    time_elapsed       | 693      |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | 0.339    |
# |    explained_variance | 0.648    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50739    |
# |    policy_loss        | 0.000924 |
# |    std                | 0.255    |
# |    value_loss         | 0.0111   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.92     |
# |    ep_rew_mean        | -0.227   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49100    |
# |    time_elapsed       | 694      |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | 0.359    |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50839    |
# |    policy_loss        | 0.00493  |
# |    std                | 0.254    |
# |    value_loss         | 0.000536 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.71     |
# |    ep_rew_mean        | -0.209   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49200    |
# |    time_elapsed       | 696      |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | 0.363    |
# |    explained_variance | 0.96     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 50939    |
# |    policy_loss        | 0.0036   |
# |    std                | 0.254    |
# |    value_loss         | 0.000352 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.68     |
# |    ep_rew_mean        | -0.209   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49300    |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | 0.358    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51039    |
# |    policy_loss        | -0.00279 |
# |    std                | 0.254    |
# |    value_loss         | 0.000217 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.72     |
# |    ep_rew_mean        | -0.21    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49400    |
# |    time_elapsed       | 699      |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | 0.367    |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51139    |
# |    policy_loss        | 0.00234  |
# |    std                | 0.254    |
# |    value_loss         | 0.000322 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49500    |
# |    time_elapsed       | 700      |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | 0.384    |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51239    |
# |    policy_loss        | 0.00516  |
# |    std                | 0.252    |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.92     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49600    |
# |    time_elapsed       | 701      |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | 0.39     |
# |    explained_variance | 0.78     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51339    |
# |    policy_loss        | 0.0269   |
# |    std                | 0.251    |
# |    value_loss         | 0.00137  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49700    |
# |    time_elapsed       | 703      |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | 0.382    |
# |    explained_variance | 0.918    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51439    |
# |    policy_loss        | 0.015    |
# |    std                | 0.251    |
# |    value_loss         | 0.000575 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49800    |
# |    time_elapsed       | 704      |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | 0.395    |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51539    |
# |    policy_loss        | -0.0123  |
# |    std                | 0.25     |
# |    value_loss         | 0.0015   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.221   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 49900    |
# |    time_elapsed       | 706      |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | 0.393    |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51639    |
# |    policy_loss        | -0.00101 |
# |    std                | 0.25     |
# |    value_loss         | 0.000382 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.221   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 50000    |
# |    time_elapsed       | 707      |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | 0.376    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 51739    |
# |    policy_loss        | 0.0108   |
# |    std                | 0.252    |
# |    value_loss         | 0.000257 |
# ------------------------------------

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-PandaReachDense-v3")
env.save("vec_normalize.pkl")

# %% [markdown]
# ### Evaluate the agent 📈
# - Now that's our  agent is trained, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

# We need to override the render_mode
eval_env.render_mode = "rgb_array"

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load("a2c-PandaReachDense-v3")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Mean reward = -0.22 +/- 0.10
# /Users/sriramsohan/miniforge3/envs/RL_env/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Publish your trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the Hub with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20

# %% [markdown]
# By using `package_to_hub`, as we already mentionned in the former units, **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# For this environment, **running this cell can take approximately 10min**

# %%
# from huggingface_sb3 import package_to_hub

# package_to_hub(
#     model=model,
#     model_name=f"a2c-{env_id}",
#     model_architecture="A2C",
#     env_id=env_id,
#     eval_env=eval_env,
#     repo_id=f"SriramSohan/a2c-{env_id}", # Change the username
#     commit_message="PreviewVideo",
# )
from huggingface_hub import HfApi

api = HfApi()
api.upload_file(
    path_or_fileobj="./videos/rl-video-step-0-to-step-200.mp4",
    path_in_repo="videos/rl-video-step-0-to-step-200.mp4",
    repo_id="SriramSohan/a2c-PandaReachDense-v3",
    repo_type="model",
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/SriramSohan/a2c-PandaReachDense-v3/commit/474eaa068516274ab60cb3a8c725770d944bce41', commit_message='Upload videos/rl-video-step-0-to-step-200.mp4 with huggingface_hub', commit_description='', oid='474eaa068516274ab60cb3a8c725770d944bce41', pr_url=None, repo_url=RepoUrl('https://huggingface.co/SriramSohan/a2c-PandaReachDense-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='SriramSohan/a2c-PandaReachDense-v3'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  `PandaPickAndPlace-v3`?
#
# If you want to try more advanced tasks for panda-gym, you need to check what was done using **TQC or SAC** (a more sample-efficient algorithm suited for robotics tasks). In real robotics, you'll use a more sample-efficient algorithm for a simple reason: contrary to a simulation **if you move your robotic arm too much, you have a risk of breaking it**.
#
# PandaPickAndPlace-v1 (this model uses the v1 version of the environment): https://huggingface.co/sb3/tqc-PandaPickAndPlace-v1
#
# And don't hesitate to check panda-gym documentation here: https://panda-gym.readthedocs.io/en/latest/usage/train_with_sb3.html
#
# We provide you the steps to train another agent (optional):
#
# 1. Define the environment called "PandaPickAndPlace-v3"
# 2. Make a vectorized environment
# 3. Add a wrapper to normalize the observations and rewards. [Check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)
# 4. Create the A2C Model (don't forget verbose=1 to print the training logs).
# 5. Train it for 1M Timesteps
# 6. Save the model and  VecNormalize statistics when saving the agent
# 7. Evaluate your agent
# 8. Publish your trained model on the Hub 🔥 with `package_to_hub`

# %% [markdown]
# ### Solution (optional)

# %%
# 1 - 2
env_id = "PandaPickAndPlace-v3"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
model.learn(1_000_000)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.8     |
# |    ep_rew_mean        | -48.8    |
# |    success_rate       | 0.025    |
# | time/                 |          |
# |    fps                | 1129     |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -1.84    |
# |    std                | 1.02     |
# |    value_loss         | 0.158    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.8     |
# |    ep_rew_mean        | -48.8    |
# |    success_rate       | 0.0247   |
# | time/                 |          |
# |    fps                | 1147     |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.685   |
# |    std                | 1.03     |
# |    value_loss         | 0.0838   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -48.9    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1146     |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -5.83    |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.312    |
# |    std                | 1.04     |
# |    value_loss         | 0.0268   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.4    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1147     |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -1.63    |
# |    std                | 1.04     |
# |    value_loss         | 0.335    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1154     |
# |    iterations         | 500      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -5.88    |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.226    |
# |    std                | 1.05     |
# |    value_loss         | 0.0293   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1150     |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -5.88    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.407   |
# |    std                | 1.05     |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.1     |
# |    ep_rew_mean        | -49.1    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1149     |
# |    iterations         | 700      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.576    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.352   |
# |    std                | 1.06     |
# |    value_loss         | 0.012    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.6     |
# |    ep_rew_mean        | -48.6    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1155     |
# |    iterations         | 800      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.286   |
# |    std                | 1.05     |
# |    value_loss         | 0.0315   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1161     |
# |    iterations         | 900      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0187  |
# |    std                | 1.06     |
# |    value_loss         | 0.0121   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1156     |
# |    iterations         | 1000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.184    |
# |    std                | 1.06     |
# |    value_loss         | 0.00452  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.7     |
# |    ep_rew_mean        | -48.6    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1153     |
# |    iterations         | 1100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0599  |
# |    std                | 1.06     |
# |    value_loss         | 0.00555  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.7     |
# |    ep_rew_mean        | -48.6    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1147     |
# |    iterations         | 1200     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.1     |
# |    std                | 1.06     |
# |    value_loss         | 0.00619  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.2     |
# |    ep_rew_mean        | -49.1    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1145     |
# |    iterations         | 1300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.14     |
# |    std                | 1.06     |
# |    value_loss         | 0.0124   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1147     |
# |    iterations         | 1400     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.223   |
# |    std                | 1.06     |
# |    value_loss         | 0.00575  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1149     |
# |    iterations         | 1500     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.202   |
# |    std                | 1.06     |
# |    value_loss         | 0.00693  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1153     |
# |    iterations         | 1600     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.668    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0914  |
# |    std                | 1.06     |
# |    value_loss         | 0.014    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1155     |
# |    iterations         | 1700     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.619    |
# |    std                | 1.06     |
# |    value_loss         | 0.0143   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1157     |
# |    iterations         | 1800     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.808    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0242   |
# |    std                | 1.06     |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.1     |
# |    ep_rew_mean        | -46      |
# |    success_rate       | 0.08     |
# | time/                 |          |
# |    fps                | 1159     |
# |    iterations         | 1900     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.86     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.13     |
# |    std                | 1.07     |
# |    value_loss         | 0.00553  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1162     |
# |    iterations         | 2000     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.913    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.245    |
# |    std                | 1.07     |
# |    value_loss         | 0.0129   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1165     |
# |    iterations         | 2100     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.596    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.358   |
# |    std                | 1.06     |
# |    value_loss         | 0.00854  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1165     |
# |    iterations         | 2200     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0632  |
# |    std                | 1.06     |
# |    value_loss         | 0.00339  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1165     |
# |    iterations         | 2300     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0122  |
# |    std                | 1.07     |
# |    value_loss         | 0.002    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1167     |
# |    iterations         | 2400     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -5.93    |
# |    explained_variance | -0.0508  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0263  |
# |    std                | 1.07     |
# |    value_loss         | 0.00227  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 2500     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -5.95    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.141   |
# |    std                | 1.07     |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 2600     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.107   |
# |    std                | 1.06     |
# |    value_loss         | 0.0022   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 2700     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.707    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.503   |
# |    std                | 1.06     |
# |    value_loss         | 0.0918   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1170     |
# |    iterations         | 2800     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -5.87    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.261   |
# |    std                | 1.05     |
# |    value_loss         | 0.00506  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 2900     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.0711  |
# |    std                | 1.06     |
# |    value_loss         | 0.00166  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 3000     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -5.89    |
# |    explained_variance | 0.927    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0765   |
# |    std                | 1.06     |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.1     |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 3100     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.823    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.189   |
# |    std                | 1.06     |
# |    value_loss         | 0.00215  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.2     |
# |    ep_rew_mean        | -47.1    |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 3200     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.188   |
# |    std                | 1.06     |
# |    value_loss         | 0.00889  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.2     |
# |    ep_rew_mean        | -46.1    |
# |    success_rate       | 0.08     |
# | time/                 |          |
# |    fps                | 1168     |
# |    iterations         | 3300     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.107    |
# |    std                | 1.07     |
# |    value_loss         | 0.00141  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.6     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1166     |
# |    iterations         | 3400     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.528    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.898    |
# |    std                | 1.06     |
# |    value_loss         | 0.128    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.1     |
# |    ep_rew_mean        | -46      |
# |    success_rate       | 0.08     |
# | time/                 |          |
# |    fps                | 1165     |
# |    iterations         | 3500     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -5.92    |
# |    explained_variance | 0.117    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.402   |
# |    std                | 1.06     |
# |    value_loss         | 0.0206   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | -46.5    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 1164     |
# |    iterations         | 3600     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.855    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0461   |
# |    std                | 1.06     |
# |    value_loss         | 0.0018   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1162     |
# |    iterations         | 3700     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.931    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0485  |
# |    std                | 1.06     |
# |    value_loss         | 0.000446 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1161     |
# |    iterations         | 3800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -5.91    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0475   |
# |    std                | 1.06     |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1157     |
# |    iterations         | 3900     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0373  |
# |    std                | 1.06     |
# |    value_loss         | 0.00174  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1156     |
# |    iterations         | 4000     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -5.9     |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0763  |
# |    std                | 1.06     |
# |    value_loss         | 0.000478 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 1152     |
# |    iterations         | 4100     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -5.87    |
# |    explained_variance | 0.829    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.00529 |
# |    std                | 1.05     |
# |    value_loss         | 0.000206 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1148     |
# |    iterations         | 4200     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -5.86    |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0276   |
# |    std                | 1.05     |
# |    value_loss         | 0.00019  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1145     |
# |    iterations         | 4300     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -5.85    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0192  |
# |    std                | 1.05     |
# |    value_loss         | 0.000194 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1143     |
# |    iterations         | 4400     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -5.84    |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.03     |
# |    std                | 1.05     |
# |    value_loss         | 0.000257 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1141     |
# |    iterations         | 4500     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -5.81    |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0402   |
# |    std                | 1.04     |
# |    value_loss         | 0.000359 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1139     |
# |    iterations         | 4600     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0293   |
# |    std                | 1.03     |
# |    value_loss         | 0.000165 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1136     |
# |    iterations         | 4700     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0261  |
# |    std                | 1.03     |
# |    value_loss         | 5.73e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1135     |
# |    iterations         | 4800     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.83     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.024    |
# |    std                | 1.03     |
# |    value_loss         | 7.4e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1133     |
# |    iterations         | 4900     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0141   |
# |    std                | 1.03     |
# |    value_loss         | 0.000368 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1131     |
# |    iterations         | 5000     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.839    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.037    |
# |    std                | 1.03     |
# |    value_loss         | 0.000146 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1128     |
# |    iterations         | 5100     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -5.8     |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0171  |
# |    std                | 1.03     |
# |    value_loss         | 5.37e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1126     |
# |    iterations         | 5200     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0435  |
# |    std                | 1.03     |
# |    value_loss         | 0.000173 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1125     |
# |    iterations         | 5300     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.00415 |
# |    std                | 1.03     |
# |    value_loss         | 9.05e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1123     |
# |    iterations         | 5400     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0132   |
# |    std                | 1.03     |
# |    value_loss         | 0.000214 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 5500     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.921    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0244   |
# |    std                | 1.02     |
# |    value_loss         | 0.000921 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1118     |
# |    iterations         | 5600     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.926    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0115  |
# |    std                | 1.02     |
# |    value_loss         | 2e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1117     |
# |    iterations         | 5700     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -5.73    |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0294  |
# |    std                | 1.02     |
# |    value_loss         | 8.64e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | -46.5    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 1116     |
# |    iterations         | 5800     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -5.69    |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0316   |
# |    std                | 1.01     |
# |    value_loss         | 0.000146 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1113     |
# |    iterations         | 5900     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.00587 |
# |    std                | 1        |
# |    value_loss         | 0.000199 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1111     |
# |    iterations         | 6000     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0192   |
# |    std                | 1        |
# |    value_loss         | 2.41e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1110     |
# |    iterations         | 6100     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -5.65    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0143   |
# |    std                | 0.996    |
# |    value_loss         | 3.47e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1108     |
# |    iterations         | 6200     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.00496 |
# |    std                | 1        |
# |    value_loss         | 5.91e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1106     |
# |    iterations         | 6300     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.000336 |
# |    std                | 1        |
# |    value_loss         | 1.58e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1105     |
# |    iterations         | 6400     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.0248   |
# |    std                | 0.994    |
# |    value_loss         | 7.24e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1104     |
# |    iterations         | 6500     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -5.63    |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00178  |
# |    std                | 0.99     |
# |    value_loss         | 2e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1102     |
# |    iterations         | 6600     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -5.61    |
# |    explained_variance | -1.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.0421   |
# |    std                | 0.987    |
# |    value_loss         | 9.41e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1102     |
# |    iterations         | 6700     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -5.61    |
# |    explained_variance | 0.964    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0218  |
# |    std                | 0.986    |
# |    value_loss         | 4.58e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1100     |
# ...
# |    fps                | 1207     |
# |    iterations         | 47800    |
# |    time_elapsed       | 791      |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | -0.238   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | 0.00198  |
# |    std                | 0.524    |
# |    value_loss         | 1.77e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.3      |
# |    ep_rew_mean        | -49.3     |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 1207      |
# |    iterations         | 47900     |
# |    time_elapsed       | 793       |
# |    total_timesteps    | 958000    |
# | train/                |           |
# |    entropy_loss       | -2.94     |
# |    explained_variance | 0.99      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47899     |
# |    policy_loss        | -0.000197 |
# |    std                | 0.525     |
# |    value_loss         | 2.81e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1207     |
# |    iterations         | 48000    |
# |    time_elapsed       | 794      |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | 0.000992 |
# |    std                | 0.522    |
# |    value_loss         | 1.84e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1208     |
# |    iterations         | 48100    |
# |    time_elapsed       | 796      |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 0.00319  |
# |    std                | 0.52     |
# |    value_loss         | 1.25e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1208     |
# |    iterations         | 48200    |
# |    time_elapsed       | 797      |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | -0.00395 |
# |    std                | 0.517    |
# |    value_loss         | 1.33e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1208     |
# |    iterations         | 48300    |
# |    time_elapsed       | 799      |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -0.00184 |
# |    std                | 0.514    |
# |    value_loss         | 2.85e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1208     |
# |    iterations         | 48400    |
# |    time_elapsed       | 800      |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | 0.01     |
# |    std                | 0.513    |
# |    value_loss         | 4.63e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 48500    |
# |    time_elapsed       | 802      |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | -0.00232 |
# |    std                | 0.51     |
# |    value_loss         | 1.31e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 48600    |
# |    time_elapsed       | 803      |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -2.8     |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.00179 |
# |    std                | 0.509    |
# |    value_loss         | 5.25e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 48700    |
# |    time_elapsed       | 805      |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | -2.79    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | -0.0024  |
# |    std                | 0.509    |
# |    value_loss         | 4.15e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 48800    |
# |    time_elapsed       | 806      |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -2.79    |
# |    explained_variance | 0.0146   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | 1.71     |
# |    std                | 0.509    |
# |    value_loss         | 3.86     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 48900    |
# |    time_elapsed       | 808      |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.679    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | -0.00137 |
# |    std                | 0.504    |
# |    value_loss         | 3.91e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 1209     |
# |    iterations         | 49000    |
# |    time_elapsed       | 809      |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | -2.74    |
# |    explained_variance | 0.218    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | -0.015   |
# |    std                | 0.502    |
# |    value_loss         | 0.000113 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49100    |
# |    time_elapsed       | 811      |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | 0.000195 |
# |    std                | 0.501    |
# |    value_loss         | 4.9e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49200    |
# |    time_elapsed       | 813      |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -0.00214 |
# |    std                | 0.502    |
# |    value_loss         | 1.52e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.2     |
# |    ep_rew_mean        | -48.2    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49300    |
# |    time_elapsed       | 814      |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.804    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | 0.000549 |
# |    std                | 0.504    |
# |    value_loss         | 1.66e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.7     |
# |    ep_rew_mean        | -48.7    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49400    |
# |    time_elapsed       | 816      |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.546    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | 0.00249  |
# |    std                | 0.504    |
# |    value_loss         | 8.35e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49500    |
# |    time_elapsed       | 817      |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | -2.76    |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | 0.00174  |
# |    std                | 0.506    |
# |    value_loss         | 3.71e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49600    |
# |    time_elapsed       | 819      |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -2.74    |
# |    explained_variance | 0.883    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | 0.00133  |
# |    std                | 0.502    |
# |    value_loss         | 8.79e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49700    |
# |    time_elapsed       | 820      |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.603    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | 0.00406  |
# |    std                | 0.501    |
# |    value_loss         | 5.27e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1210     |
# |    iterations         | 49800    |
# |    time_elapsed       | 822      |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -2.72    |
# |    explained_variance | 0.924    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | 0.00128  |
# |    std                | 0.5      |
# |    value_loss         | 7.29e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 1211     |
# |    iterations         | 49900    |
# |    time_elapsed       | 824      |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -2.72    |
# |    explained_variance | 0.00995  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | 0.67     |
# |    std                | 0.498    |
# |    value_loss         | 3.86     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 1211     |
# |    iterations         | 50000    |
# |    time_elapsed       | 825      |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -2.71    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | -0.0025  |
# |    std                | 0.499    |
# |    value_loss         | 1.92e-06 |
# ------------------------------------

# %%
# 6
model_name = "a2c-PandaPickAndPlace-v3";
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaPickAndPlace-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"SriramSohan/a2c-{env_id}", # TODO: Change the username
    commit_message="Balancing Cubes",
)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Mean reward = -45.00 +/- 15.00
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/tmpfq15aab8/-step-0-to-step-1000.mp4
# MoviePy - Building video /var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/tmpfq15aab8/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/tmpfq15aab8/-step-0-to-step-1000.mp4
# MoviePy - Done !
# MoviePy - video ready /var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/tmpfq15aab8/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo SriramSohan/a2c-PandaPickAndPlace-v3 to the Hugging Face
# Hub
# a2c-PandaPickAndPlace-v3.zip:   0%|          | 0.00/130k [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# vec_normalize.pkl:   0%|          | 0.00/3.04k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/SriramSohan/a2c-PandaPickAndPlace-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/SriramSohan/a2c-PandaPickAndPlace-v3/commit/6caa20c7d29ceef141dce5045d83eec5d56530d9', commit_message='Balancing Cubes', commit_description='', oid='6caa20c7d29ceef141dce5045d83eec5d56530d9', pr_url=None, repo_url=RepoUrl('https://huggingface.co/SriramSohan/a2c-PandaPickAndPlace-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='SriramSohan/a2c-PandaPickAndPlace-v3'), pr_revision=None, pr_num=None)

# %% [markdown]
# See you on Unit 7! 🔥
# ## Keep learning, stay awesome 🤗
