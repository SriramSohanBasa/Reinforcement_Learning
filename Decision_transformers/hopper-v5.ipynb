# %%
pip install git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /private/var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/pip-req-build-p9fu2qmj
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /private/var/folders/9v/q5zsxfwx7p12414rj_w1zmqr0000gn/T/pip-req-build-p9fu2qmj
#   Resolved https://github.com/huggingface/transformers to commit 234168c4dc837da10c594408f15807a1d6f3fab4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from transformers==4.49.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.49.0.dev0) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests->transformers==4.49.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests->transformers==4.49.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests->transformers==4.49.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests->transformers==4.49.0.dev0) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import DecisionTransformerModel

model_name = "edbeeching/decision-transformer-gym-hopper-expert"
model = DecisionTransformerModel.from_pretrained(model_name)

# %%
# !pip install glfw
# !pip install mujoco
# !pip install gymnasium
# !pip install numpy
# !pip install gymnasium moviepy
# !pip install gymnasium[mujoco]
# !pip install imageio
# Out:
# Requirement already satisfied: glfw in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: mujoco in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: absl-py in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from mujoco) (2.1.0)
# Requirement already satisfied: glfw in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from mujoco) (2.8.0)
# Requirement already satisfied: numpy in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from mujoco) (1.23.5)
# Requirement already satisfied: pyopengl in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from mujoco) (3.1.9)
# Requirement already satisfied: gymnasium in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: numpy in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: gymnasium in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: moviepy in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (2.36.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pillow>=8.3.2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from imageio<3.0,>=2.5->moviepy) (10.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (2024.12.14)
# zsh:1: no matches found: gymnasium[mujoco]
# Requirement already satisfied: imageio in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (2.36.1)
# Requirement already satisfied: numpy in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages (from imageio) (10.4.0)

# %%
import os
os.environ['MUJOCO_GL'] = 'glfw'

# %%
import numpy as np
import torch
import gymnasium as gym
from gymnasium.wrappers import RecordVideo

# %%
# Constants
TARGET_RETURN = 3.6  # Normalized during training
max_ep_len = 1000

state_mean = np.array(
    [1.3490015, -0.11208222, -0.5506444, -0.13188992, -0.00378754, 2.6071432,
     0.02322114, -0.01626922, -0.06840388, -0.05183131, 0.04272673]
)

state_std = np.array(
    [0.15980862, 0.0446214, 0.14307782, 0.17629202, 0.5912333, 0.5899924,
     1.5405099, 0.8152689, 2.0173461, 2.4107876, 5.8440027]
)

state_mean = torch.from_numpy(state_mean)
state_std = torch.from_numpy(state_std)

# %%
# Wrap the environment for recording
env = gym.make("Hopper-v5", render_mode="rgb_array")
env = RecordVideo(env, video_folder="./videos", episode_trigger=lambda x: True)

state, info = env.reset()
state_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]
# Out:
# /Users/sriramsohan/miniforge3/envs/Unity_Agents_env/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/sriramsohan/Documents/projects/Reinforcement_Learning/Decision_transformers/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
print(state_dim)
print(act_dim)
import gymnasium as gym
print(gym.__version__)
# Out:
# 11
# 3
# 1.0.0

# %%
# Initialize variables
target_return = torch.tensor(TARGET_RETURN).float().reshape(1, 1)
states = torch.from_numpy(state).reshape(1, state_dim).float()
actions = torch.zeros((0, act_dim)).float()
rewards = torch.zeros(0).float()
timesteps = torch.tensor(0).reshape(1, 1).long()

# %%
def get_action(model, states, actions, rewards, returns_to_go, timesteps):
    states = states.reshape(1, -1, model.config.state_dim)
    actions = actions.reshape(1, -1, model.config.act_dim)
    returns_to_go = returns_to_go.reshape(1, -1, 1)
    timesteps = timesteps.reshape(1, -1)

    states = states[:, -model.config.max_length:]
    actions = actions[:, -model.config.max_length:]
    returns_to_go = returns_to_go[:, -model.config.max_length:]
    timesteps = timesteps[:, -model.config.max_length:]

    # Padding for sequence
    padding = model.config.max_length - states.shape[1]
    attention_mask = torch.cat([torch.zeros(padding), torch.ones(states.shape[1])])
    attention_mask = attention_mask.to(dtype=torch.long).reshape(1, -1)
    states = torch.cat([torch.zeros((1, padding, state_dim)), states], dim=1).float()
    actions = torch.cat([torch.zeros((1, padding, act_dim)), actions], dim=1).float()
    returns_to_go = torch.cat([torch.zeros((1, padding, 1)), returns_to_go], dim=1).float()
    timesteps = torch.cat([torch.zeros((1, padding), dtype=torch.long), timesteps], dim=1)

    state_preds, action_preds, return_preds = model(
        states=states,
        actions=actions,
        rewards=rewards,
        returns_to_go=returns_to_go,
        timesteps=timesteps,
        attention_mask=attention_mask,
        return_dict=False,
    )
    return action_preds[0, -1]

# %%
# Take steps in the environment
for t in range(max_ep_len):
    actions = torch.cat([actions, torch.zeros((1, act_dim))], dim=0)
    rewards = torch.cat([rewards, torch.zeros(1)])

    action = get_action(
        model,
        (states - state_mean) / state_std,
        actions,
        rewards,
        target_return,
        timesteps
    )
    actions[-1] = action
    action = action.detach().numpy()

    state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    cur_state = torch.from_numpy(state).reshape(1, state_dim)
    states = torch.cat([states, cur_state], dim=0)
    rewards[-1] = reward

    pred_return = target_return[0, -1] - (reward / TARGET_RETURN)
    target_return = torch.cat([target_return, pred_return.reshape(1, 1)], dim=1)
    timesteps = torch.cat([timesteps, torch.ones((1, 1)).long() * (t + 1)], dim=1)

    if done:
        break

env.close()

# Display video
import os
from IPython.display import Video

video_path = os.path.join("./videos", os.listdir("./videos")[0])  # Get first video file
Video(video_path, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from huggingface_hub import HfApi, upload_folder
import torch
import tempfile
from pathlib import Path
import json
import datetime
import shutil

# %%
from huggingface_hub import HfApi
import torch
import tempfile
from pathlib import Path
import json
import datetime
import shutil
import os
from huggingface_hub.repocard import metadata_eval_result, metadata_save

def push_to_hub(
    repo_id="SriramSohan/hopper-v5",
    model=None,
    eval_env=None,
    video_fps=30
):
    _, repo_name = repo_id.split("/")
    api = HfApi()

    # Create (or reuse) the repo on the Hub
    repo_url = api.create_repo(
        repo_id=repo_id,
        exist_ok=True,
    )

    with tempfile.TemporaryDirectory() as tmpdirname:
        local_directory = Path(tmpdirname)

        # 1. Save model
        torch.save(model.state_dict(), local_directory / "model.pt")

        # 2. Save hyperparameters
        hyperparameters = {
            "env_id": "Hopper-v5",
            "max_ep_len": 1000,
            "state_dim": 11,
            "act_dim": 3,
            "target_return": 3.6,
            "state_mean": state_mean.tolist(),
            "state_std": state_std.tolist()
        }
        with open(local_directory / "hyperparameters.json", "w") as outfile:
            json.dump(hyperparameters, outfile)

        # 3. Copy existing video (from ./videos folder)
        video_path = os.path.join("./videos", os.listdir("./videos")[0])
        shutil.copy2(video_path, local_directory / "replay.mp4")

        # 4. Create results.json
        eval_data = {
            "env_id": "Hopper-v5",
            "eval_datetime": datetime.datetime.now().isoformat(),
        }
        with open(local_directory / "results.json", "w") as outfile:
            json.dump(eval_data, outfile)

        # 5. Create README.md with metadata
        model_card = """---
tags:
- Hopper-v5
- reinforcement-learning
- decision-transformer
- deep-reinforcement-learning
- custom-implementation
library_name: transformers
---

# Decision Transformer for Hopper-v5

This is a trained Decision Transformer model for the Hopper-v5 environment.

## Model Details
- Environment: Hopper-v5
- Model: Decision Transformer
- Training framework: PyTorch

## Hyperparameters
{
  "max_ep_len": 1000,
  "state_dim": 11,
  "act_dim": 3,
  "target_return": 3.6
}

## Video Preview
The model demonstrates the hopping behavior learned through Decision Transformer training.
"""
        with open(local_directory / "README.md", "w", encoding="utf-8") as f:
            f.write(model_card)

        # 6. Push everything to the Hub
        api.upload_folder(
            repo_id=repo_id,
            folder_path=local_directory,
            path_in_repo=".",  # Push all files in this temporary directory
        )

    # Print the final URL
    print(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
    return repo_url


push_to_hub(
    repo_id="SriramSohan/hopper-v5",
    model=model,
    eval_env=env
)
# Out:
# Your model is pushed to the Hub. You can view your model here: https://huggingface.co/SriramSohan/hopper-v5
# RepoUrl('https://huggingface.co/SriramSohan/hopper-v5', endpoint='https://huggingface.co', repo_type='model', repo_id='SriramSohan/hopper-v5')
